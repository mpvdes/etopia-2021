# %%
import pandas as pd

# %%
url = 'https://api.covid19api.com/countries'

# %%
df = pd.read_json(url)

# %%
df
# Out:
#                   Country                  Slug ISO2
# 0                Slovakia              slovakia   SK
# 1                 Uruguay               uruguay   UY
# 2                  Serbia                serbia   RS
# 3           Côte d'Ivoire          cote-divoire   CI
# 4           Guinea-Bissau         guinea-bissau   GW
# ..                    ...                   ...  ...
# 243              Suriname              suriname   SR
# 244  United Arab Emirates  united-arab-emirates   AE
# 245                 Egypt                 egypt   EG
# 246           El Salvador           el-salvador   SV
# 247                Monaco                monaco   MC
#
# [248 rows x 3 columns]

# %%
df.head()
# Out:
#          Country           Slug ISO2
# 0       Slovakia       slovakia   SK
# 1        Uruguay        uruguay   UY
# 2         Serbia         serbia   RS
# 3  Côte d'Ivoire   cote-divoire   CI
# 4  Guinea-Bissau  guinea-bissau   GW

# %%
df.tail()
# Out:
#                   Country                  Slug ISO2
# 243              Suriname              suriname   SR
# 244  United Arab Emirates  united-arab-emirates   AE
# 245                 Egypt                 egypt   EG
# 246           El Salvador           el-salvador   SV
# 247                Monaco                monaco   MC

# %%
df['Country'][245]
# Out:
# 'Egypt'

# %%
df[df['Country'] == 'Spain']

# %% [markdown]
# ### Sudáfrica

# %%
url = 'https://api.covid19api.com/country/south-africa/status/confirmed/live'
sa = pd.read_json(url)
sa
# Out:
#           Country CountryCode Province City CityCode    Lat    Lon    Cases  \
# 0    South Africa          ZA                        -30.56  22.94        0
# 1    South Africa          ZA                        -30.56  22.94        0
# 2    South Africa          ZA                        -30.56  22.94        0
# 3    South Africa          ZA                        -30.56  22.94        0
# 4    South Africa          ZA                        -30.56  22.94        0
# ..            ...         ...      ...  ...      ...    ...    ...      ...
# 656  South Africa          ZA                        -30.56  22.94  2924072
# 657  South Africa          ZA                        -30.56  22.94  2924317
# 658  South Africa          ZA                        -30.56  22.94  2924622
# 659  South Africa          ZA                        -30.56  22.94  2924978
# 660  South Africa          ZA                        -30.56  22.94  2925371
#
#         Status                      Date
# 0    confirmed 2020-01-22 00:00:00+00:00
# 1    confirmed 2020-01-23 00:00:00+00:00
# 2    confirmed 2020-01-24 00:00:00+00:00
# 3    confirmed 2020-01-25 00:00:00+00:00
# 4    confirmed 2020-01-26 00:00:00+00:00
# ..         ...                       ...
# 656  confirmed 2021-11-08 00:00:00+00:00
# 657  confirmed 2021-11-09 00:00:00+00:00
# 658  confirmed 2021-11-10 00:00:00+00:00
# 659  confirmed 2021-11-11 00:00:00+00:00
# 660  confirmed 2021-11-13 00:00:00+00:00
#
# [661 rows x 10 columns]

# %% [markdown]
# set_index es como el key column de Refine

# %%
sa
# Out:
#           Country CountryCode Province City CityCode    Lat    Lon    Cases  \
# 0    South Africa          ZA                        -30.56  22.94        0
# 1    South Africa          ZA                        -30.56  22.94        0
# 2    South Africa          ZA                        -30.56  22.94        0
# 3    South Africa          ZA                        -30.56  22.94        0
# 4    South Africa          ZA                        -30.56  22.94        0
# ..            ...         ...      ...  ...      ...    ...    ...      ...
# 656  South Africa          ZA                        -30.56  22.94  2924072
# 657  South Africa          ZA                        -30.56  22.94  2924317
# 658  South Africa          ZA                        -30.56  22.94  2924622
# 659  South Africa          ZA                        -30.56  22.94  2924978
# 660  South Africa          ZA                        -30.56  22.94  2925371
#
#         Status                      Date
# 0    confirmed 2020-01-22 00:00:00+00:00
# 1    confirmed 2020-01-23 00:00:00+00:00
# 2    confirmed 2020-01-24 00:00:00+00:00
# 3    confirmed 2020-01-25 00:00:00+00:00
# 4    confirmed 2020-01-26 00:00:00+00:00
# ..         ...                       ...
# 656  confirmed 2021-11-08 00:00:00+00:00
# 657  confirmed 2021-11-09 00:00:00+00:00
# 658  confirmed 2021-11-10 00:00:00+00:00
# 659  confirmed 2021-11-11 00:00:00+00:00
# 660  confirmed 2021-11-13 00:00:00+00:00
#
# [661 rows x 10 columns]

# %%
sa.set_index('Date')
# Out:
#                                 Country CountryCode Province City CityCode  \
# Date
# 2020-01-22 00:00:00+00:00  South Africa          ZA
# 2020-01-23 00:00:00+00:00  South Africa          ZA
# 2020-01-24 00:00:00+00:00  South Africa          ZA
# 2020-01-25 00:00:00+00:00  South Africa          ZA
# 2020-01-26 00:00:00+00:00  South Africa          ZA
# ...                                 ...         ...      ...  ...      ...
# 2021-11-08 00:00:00+00:00  South Africa          ZA
# 2021-11-09 00:00:00+00:00  South Africa          ZA
# 2021-11-10 00:00:00+00:00  South Africa          ZA
# 2021-11-11 00:00:00+00:00  South Africa          ZA
# 2021-11-13 00:00:00+00:00  South Africa          ZA
#
#                              Lat    Lon    Cases     Status
# Date
# 2020-01-22 00:00:00+00:00 -30.56  22.94        0  confirmed
# 2020-01-23 00:00:00+00:00 -30.56  22.94        0  confirmed
# 2020-01-24 00:00:00+00:00 -30.56  22.94        0  confirmed
# 2020-01-25 00:00:00+00:00 -30.56  22.94        0  confirmed
# 2020-01-26 00:00:00+00:00 -30.56  22.94        0  confirmed
# ...                          ...    ...      ...        ...
# 2021-11-08 00:00:00+00:00 -30.56  22.94  2924072  confirmed
# 2021-11-09 00:00:00+00:00 -30.56  22.94  2924317  confirmed
# 2021-11-10 00:00:00+00:00 -30.56  22.94  2924622  confirmed
# 2021-11-11 00:00:00+00:00 -30.56  22.94  2924978  confirmed
# 2021-11-13 00:00:00+00:00 -30.56  22.94  2925371  confirmed
#
# [661 rows x 9 columns]

# %% [markdown]
# En plot dibuja en x el indice

# %%
sa.set_index('Date')['Cases']
# Out:
# Date
# 2020-01-22 00:00:00+00:00          0
# 2020-01-23 00:00:00+00:00          0
# 2020-01-24 00:00:00+00:00          0
# 2020-01-25 00:00:00+00:00          0
# 2020-01-26 00:00:00+00:00          0
#                               ...
# 2021-11-08 00:00:00+00:00    2924072
# 2021-11-09 00:00:00+00:00    2924317
# 2021-11-10 00:00:00+00:00    2924622
# 2021-11-11 00:00:00+00:00    2924978
# 2021-11-13 00:00:00+00:00    2925371
# Name: Cases, Length: 661, dtype: int64

# %%
sa.set_index('Date')['Cases'].plot()
# Out:
# <AxesSubplot:title={'center':'sudafrica'}, xlabel='Date'>

# %% [markdown]
# ## Alemania
#
# Ahora vamos a cargar los daos de Alemania

# %%
url = 'https://api.covid19api.com/country/germany/status/confirmed/live'
de = pd.read_json(url)
de
# Out:
#      Country CountryCode Province City CityCode    Lat    Lon    Cases  \
# 0    Germany          DE                         51.17  10.45        0
# 1    Germany          DE                         51.17  10.45        0
# 2    Germany          DE                         51.17  10.45        0
# 3    Germany          DE                         51.17  10.45        0
# 4    Germany          DE                         51.17  10.45        0
# ..       ...         ...      ...  ...      ...    ...    ...      ...
# 655  Germany          DE                         51.17  10.45  4792463
# 656  Germany          DE                         51.17  10.45  4816177
# 657  Germany          DE                         51.17  10.45  4857463
# 658  Germany          DE                         51.17  10.45  4908540
# 659  Germany          DE                         51.17  10.45  4957374
#
#         Status                      Date
# 0    confirmed 2020-01-22 00:00:00+00:00
# 1    confirmed 2020-01-23 00:00:00+00:00
# 2    confirmed 2020-01-24 00:00:00+00:00
# 3    confirmed 2020-01-25 00:00:00+00:00
# 4    confirmed 2020-01-26 00:00:00+00:00
# ..         ...                       ...
# 655  confirmed 2021-11-07 00:00:00+00:00
# 656  confirmed 2021-11-08 00:00:00+00:00
# 657  confirmed 2021-11-09 00:00:00+00:00
# 658  confirmed 2021-11-10 00:00:00+00:00
# 659  confirmed 2021-11-11 00:00:00+00:00
#
# [660 rows x 10 columns]

# %%
de.set_index('Date')['Cases'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
casos_de = de.set_index('Date')['Cases']
casos_sa = sa.set_index('Date')['Cases']

# %%
casos_de
# Out:
# Date
# 2020-01-22 00:00:00+00:00          0
# 2020-01-23 00:00:00+00:00          0
# 2020-01-24 00:00:00+00:00          0
# 2020-01-25 00:00:00+00:00          0
# 2020-01-26 00:00:00+00:00          0
#                               ...
# 2021-11-07 00:00:00+00:00    4792463
# 2021-11-08 00:00:00+00:00    4816177
# 2021-11-09 00:00:00+00:00    4857463
# 2021-11-10 00:00:00+00:00    4908540
# 2021-11-11 00:00:00+00:00    4957374
# Name: Cases, Length: 660, dtype: int64

# %%
casos_de = de.set_index('Date')['Cases']
casos_sa = sa.set_index('Date')['Cases']

# %%
casos_sa
# Out:
# Date
# 2020-01-22 00:00:00+00:00          0
# 2020-01-23 00:00:00+00:00          0
# 2020-01-24 00:00:00+00:00          0
# 2020-01-25 00:00:00+00:00          0
# 2020-01-26 00:00:00+00:00          0
#                               ...
# 2021-11-08 00:00:00+00:00    2924072
# 2021-11-09 00:00:00+00:00    2924317
# 2021-11-10 00:00:00+00:00    2924622
# 2021-11-11 00:00:00+00:00    2924978
# 2021-11-13 00:00:00+00:00    2925371
# Name: Cases, Length: 661, dtype: int64

# %% [markdown]
# concatenamos los dos

# %%
pd.concat([casos_de,casos_sa],axis=1)
# Out:
#                                Cases    Cases
# Date
# 2020-01-22 00:00:00+00:00        0.0        0
# 2020-01-23 00:00:00+00:00        0.0        0
# 2020-01-24 00:00:00+00:00        0.0        0
# 2020-01-25 00:00:00+00:00        0.0        0
# 2020-01-26 00:00:00+00:00        0.0        0
# ...                              ...      ...
# 2021-11-08 00:00:00+00:00  4816177.0  2924072
# 2021-11-09 00:00:00+00:00  4857463.0  2924317
# 2021-11-10 00:00:00+00:00  4908540.0  2924622
# 2021-11-11 00:00:00+00:00  4957374.0  2924978
# 2021-11-13 00:00:00+00:00        NaN  2925371
#
# [661 rows x 2 columns]

# %%
agregados = pd.concat([casos_de,casos_sa],axis=1)

# %%
agregados.columns = ['alemania','sudafrica']
# Out:
#                             alemania  sudafrica
# Date
# 2020-01-22 00:00:00+00:00        0.0          0
# 2020-01-23 00:00:00+00:00        0.0          0
# 2020-01-24 00:00:00+00:00        0.0          0
# 2020-01-25 00:00:00+00:00        0.0          0
# 2020-01-26 00:00:00+00:00        0.0          0
# ...                              ...        ...
# 2021-11-08 00:00:00+00:00  4816177.0    2924072
# 2021-11-09 00:00:00+00:00  4857463.0    2924317
# 2021-11-10 00:00:00+00:00  4908540.0    2924622
# 2021-11-11 00:00:00+00:00  4957374.0    2924978
# 2021-11-13 00:00:00+00:00        NaN    2925371
#
# [661 rows x 2 columns]

# %%
agregados.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
agregados.tail(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
url = 'https://api.covid19api.com/country/spain/status/confirmed/live'
es = pd.read_json(url)

# %%
casos_es = es.set_index('Date')['Cases']

# %%
agregados = pd.concat([casos_de,casos_sa,casos_es],axis=1)

# %%
agregados.columns = ['alemania','sudafrica','españa']
agregados.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
agregados.to_csv('agregados_DE_SA_ES.csv')
