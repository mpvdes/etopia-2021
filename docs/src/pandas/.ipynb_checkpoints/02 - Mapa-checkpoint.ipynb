# %% [markdown]
# # Accidentes en tráfico en Zaragoza
#
# ¿Qué vamos a hacer?
#
#  * obtener los datos
#  * transformar el campo coordenadas
#  * construir un tabla con motivo del accidente, latitud y longitud
#
# ## Origen de datos
#
#
# https://www.zaragoza.es/sede/servicio/catalogo/1500#API
#
# El delimitador es el **;**
# Tiene dos parámetros, rows y start

# %%
import pandas as pd
import folium

# %%
url = 'https://www.zaragoza.es/sede/servicio/transporte/accidentalidad-trafico/accidente.csv?rows=100'

# %%
df = pd.read_csv(url,delimiter=';')

# %%
df
# Out:
#                                                    id  year  \
# 0   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 1   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 2   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 3   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4   https://www.zaragoza.es/sede/servicio/transpor...  2014
# ..                                                ...   ...
# 95  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 96  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 97  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 98  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 99  https://www.zaragoza.es/sede/servicio/transpor...  2014
#
#                    type  accidentType                   firstAddress  \
# 0        SALIDA CALZADA           NaN                 COSTA, JOAQUIN
# 1      COLISIÓN ALCANCE           NaN          CADENA(MARQUES DE LA)
# 2      COLISIÓN ALCANCE           NaN           GOMEZ AVELLANEDA, G.
# 3   COLIS FRONTOLATERAL           NaN                         MONZON
# 4        SALIDA CALZADA           NaN                          RIOJA
# ..                  ...           ...                            ...
# 95                OTRAS           NaN                 MIRAL, DOMINGO
# 96     COLISIÓN ALCANCE           NaN  BUÑUEL,LUIS (PARQUE DEL AGUA)
# 97       SALIDA CALZADA           NaN              ALBAR, MANUEL GL.
# 98  COLIS FRONTOLATERAL           NaN          ECHEGARAY Y CABALLERO
# 99       SALIDA CALZADA           NaN            CESAR AUGUSTO, AVDA
#
#              secondAddress                                geometry  \
# 0             PERAL, ISAAC  -0.8818527060979306,41.649027473051156
# 1                      NaN  -0.8645810716721081,41.661585829868585
# 2       CASTRO, R. (POETA)   -0.887776415002892,41.666992622958105
# 3        GARCIA CONDOY, H.   -0.8825260453930127,41.62957498750602
# 4      NAVARRA, AVENIDA DE     -0.908314757720389,41.6562121210704
# ..                     ...                                     ...
# 95                     NaN   -0.8990662796872798,41.63977012001253
# 96                     NaN  -0.9072756956226459,41.670910841846876
# 97  ILUSTRACION, AV. DE LA   -0.9226018969034585,41.62757051008441
# 98        SAN VICENTE PAUL   -0.8735234620830842,41.65507219335992
# 99                     NaN   -0.8869504077778204,41.65022964156985
#
#                                           reason    area  \
# 0      PERDIDA del control por FALTA de ATENCIÓN     NaN
# 1            DISTANCIA DE SEGURIDAD, no mantener  2560.0
# 2      PERDIDA del control por FALTA de ATENCIÓN  2598.0
# 3    CEDA EL PASO, no respetar prioridad de paso  2555.0
# 4   PERDIDA del control por VELOCIDAD INADECUADA  2554.0
# ..                                           ...     ...
# 95     PERDIDA del control por FALTA de ATENCIÓN     NaN
# 96     PERDIDA del control por FALTA de ATENCIÓN  2071.0
# 97     PERDIDA del control por FALTA de ATENCIÓN  1969.0
# 98       SEMÁFORO, no respetar prioridad de paso  1970.0
# 99     PERDIDA del control por FALTA de ATENCIÓN  1971.0
#
#             creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0   2014-10-09T00:00:00Z              True          False     BUEN ESTADO
# 1   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 2   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 3   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 4   2014-10-24T00:00:00Z             False          False     BUEN ESTADO
# ..                   ...               ...            ...             ...
# 95  2014-07-30T00:00:00Z              True          False     BUEN ESTADO
# 96  2014-07-31T00:00:00Z              True          False     BUEN ESTADO
# 97  2014-07-25T00:00:00Z             False          False     BUEN ESTADO
# 98  2014-07-26T00:00:00Z             False          False     BUEN ESTADO
# 99  2014-07-09T00:00:00Z              True          False     BUEN ESTADO
#
#     tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                   NaN     BUEN ESTADO                  NaN
# 1                   NaN     BUEN ESTADO                  NaN
# 2                   NaN     BUEN ESTADO                  NaN
# 3                   NaN     BUEN ESTADO                  NaN
# 4                   NaN     BUEN ESTADO                  NaN
# ..                  ...             ...                  ...
# 95                  NaN     BUEN ESTADO                  NaN
# 96                  NaN     BUEN ESTADO                  NaN
# 97                  NaN     BUEN ESTADO                  NaN
# 98                  NaN     BUEN ESTADO                  NaN
# 99                  NaN     BUEN ESTADO                  NaN
#
#                                              afectado  \
# 0                                                 NaN
# 1   https://www.zaragoza.es/sede/servicio/transpor...
# 2   https://www.zaragoza.es/sede/servicio/transpor...
# 3   https://www.zaragoza.es/sede/servicio/transpor...
# 4   https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  https://www.zaragoza.es/sede/servicio/transpor...
# 98  https://www.zaragoza.es/sede/servicio/transpor...
# 99                                                NaN
#
#                                              vehiculo
# 0   https://www.zaragoza.es/sede/servicio/transpor...
# 1   https://www.zaragoza.es/sede/servicio/transpor...
# 2   https://www.zaragoza.es/sede/servicio/transpor...
# 3   https://www.zaragoza.es/sede/servicio/transpor...
# 4   https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                ...
# 95  https://www.zaragoza.es/sede/servicio/transpor...
# 96  https://www.zaragoza.es/sede/servicio/transpor...
# 97  https://www.zaragoza.es/sede/servicio/transpor...
# 98  https://www.zaragoza.es/sede/servicio/transpor...
# 99  https://www.zaragoza.es/sede/servicio/transpor...
#
# [100 rows x 18 columns]

# %% [markdown]
# Aquí tenemos todos los datos pero mejor si lo evitamos, son 27000 accidentes y puede ir lento.

# %%
df = pd.read_csv('http://muimota.net/ojoaldato/accidentes.csv')
df
# Out:
#                                                       id  year  \
# 0      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 1      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 2      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 3      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4      https://www.zaragoza.es/sede/servicio/transpor...  2014
# ...                                                  ...   ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27496  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27497  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27498  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27499  https://www.zaragoza.es/sede/servicio/transpor...  2019
#
#                       type  accidentType             firstAddress  \
# 0           SALIDA CALZADA           NaN           COSTA, JOAQUIN
# 1         COLISIÓN ALCANCE           NaN    CADENA(MARQUES DE LA)
# 2         COLISIÓN ALCANCE           NaN     GOMEZ AVELLANEDA, G.
# 3      COLIS FRONTOLATERAL           NaN                   MONZON
# 4           SALIDA CALZADA           NaN                    RIOJA
# ...                    ...           ...                      ...
# 27495     COLISIÓN LATERAL           NaN            PLEYADES, LAS
# 27496     COLISIÓN LATERAL           NaN         UNIVERSITAS, VIA
# 27497     COLISIÓN LATERAL           NaN         CANOVAS, ANTONIO
# 27498       SALIDA CALZADA           NaN     LEGAZ LACAMBRA, LUIS
# 27499     COLISIÓN LATERAL           NaN  RODRIGUEZ AYUSO, MANUEL
#
#               secondAddress                                geometry  \
# 0              PERAL, ISAAC  -0.8818527060979306,41.649027473051156
# 1                       NaN  -0.8645810716721081,41.661585829868585
# 2        CASTRO, R. (POETA)   -0.887776415002892,41.666992622958105
# 3         GARCIA CONDOY, H.   -0.8825260453930127,41.62957498750602
# 4       NAVARRA, AVENIDA DE     -0.908314757720389,41.6562121210704
# ...                     ...                                     ...
# 27495                BOYERO   -0.9337782877014544,41.63888841722081
# 27496                   NaN  -0.9067375759951974,41.644789184898926
# 27497                   NaN   -0.8907497377774148,41.64811436227578
# 27498  GOMEZ AVELLANEDA, G.  -0.8908180267513072,41.676074625860785
# 27499                  BIEL  -0.9245669583272559,41.645615385662296
#
#                                                   reason    area  \
# 0              PERDIDA del control por FALTA de ATENCIÓN     NaN
# 1                    DISTANCIA DE SEGURIDAD, no mantener  2560.0
# 2              PERDIDA del control por FALTA de ATENCIÓN  2598.0
# 3            CEDA EL PASO, no respetar prioridad de paso  2555.0
# 4           PERDIDA del control por VELOCIDAD INADECUADA  2554.0
# ...                                                  ...     ...
# 27495          INCORPORARSE sin las debidas precauciones  2512.0
# 27496          INCORPORARSE sin las debidas precauciones  2513.0
# 27497  INVADIR otro carril en el mismo sentido de cir...  2707.0
# 27498          PERDIDA del control por FALTA de ATENCIÓN  2572.0
# 27499  INVADIR otro carril en el mismo sentido de cir...  2540.0
#
#                creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0      2014-10-09T00:00:00Z              True          False     BUEN ESTADO
# 1      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 2      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 3      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 4      2014-10-24T00:00:00Z             False          False     BUEN ESTADO
# ...                     ...               ...            ...             ...
# 27495  2019-09-20T00:00:00Z             False          False     BUEN ESTADO
# 27496  2019-09-18T00:00:00Z              True          False     BUEN ESTADO
# 27497  2019-09-21T00:00:00Z              True          False     BUEN ESTADO
# 27498  2019-09-22T00:00:00Z              True          False     BUEN ESTADO
# 27499  2019-09-20T00:00:00Z             False          False     BUEN ESTADO
#
#        tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                      NaN     BUEN ESTADO                  NaN
# 1                      NaN     BUEN ESTADO                  NaN
# 2                      NaN     BUEN ESTADO                  NaN
# 3                      NaN     BUEN ESTADO                  NaN
# 4                      NaN     BUEN ESTADO                  NaN
# ...                    ...             ...                  ...
# 27495                  NaN     BUEN ESTADO                  NaN
# 27496                  NaN     BUEN ESTADO                  NaN
# 27497                  NaN     BUEN ESTADO                  NaN
# 27498                  NaN     BUEN ESTADO                  NaN
# 27499                  NaN     BUEN ESTADO                  NaN
#
#                                                 afectado  \
# 0                                                    NaN
# 1      https://www.zaragoza.es/sede/servicio/transpor...
# 2      https://www.zaragoza.es/sede/servicio/transpor...
# 3      https://www.zaragoza.es/sede/servicio/transpor...
# 4      https://www.zaragoza.es/sede/servicio/transpor...
# ...                                                  ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...
# 27496                                                NaN
# 27497                                                NaN
# 27498                                                NaN
# 27499  https://www.zaragoza.es/sede/servicio/transpor...
#
#                                                 vehiculo
# 0      https://www.zaragoza.es/sede/servicio/transpor...
# 1      https://www.zaragoza.es/sede/servicio/transpor...
# 2      https://www.zaragoza.es/sede/servicio/transpor...
# 3      https://www.zaragoza.es/sede/servicio/transpor...
# 4      https://www.zaragoza.es/sede/servicio/transpor...
# ...                                                  ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...
# 27496  https://www.zaragoza.es/sede/servicio/transpor...
# 27497  https://www.zaragoza.es/sede/servicio/transpor...
# 27498  https://www.zaragoza.es/sede/servicio/transpor...
# 27499  https://www.zaragoza.es/sede/servicio/transpor...
#
# [27500 rows x 18 columns]

# %%
df['reason'].unique()
# Out:
# array(['PERDIDA del control por FALTA de ATENCIÓN',
#        'DISTANCIA DE SEGURIDAD, no mantener',
#        'CEDA EL PASO, no respetar prioridad de paso',
#        'PERDIDA del control por VELOCIDAD INADECUADA',
#        'Caída de ocupante en Transporte Público',
#        'PEATÓN cruza calz SIN PREFER. fuera de paso',
#        'INVADIR otro carril en el mismo sentido de circulación',
#        'PEATÓN cruza calz SIN PREFER. en PASO CON semáforo',
#        'PUERTA abierta incorrectamente', 'MARCHA ATRÁS',
#        'SEMÁFORO, no respetar prioridad de paso', 'OTRAS CAUSAS',
#        'PEATÓN cruza calz CON PREFER. en PASO  CON semáforo',
#        'PEATÓN cruza calz CON PREFER. en PASO  SIN semáforo',
#        'PEATÓN cruza calz CON PREFER. en PASO SIN semáforo',
#        'INCORPORARSE sin las debidas precauciones',
#        'GIROS: no respetar señal ó no ceñirse a la dirección',
#        'PEATÓN cruza calz CON PREFER. en PASO CON semáforo',
#        'Infracción Penal (con denuncia)',
#        'PEATÓN atropellado sobre la acera ó refugio',
#        'PEATÓN cruza calz SIN PREFER. en PASO  CON semáforo',
#        'STOP, no respetar prioridad de paso',
#        'SIN PODER DETERMINAR,  faltan datos',
#        'INVADIR otro carril en sentido contrario a la circulación',
#        'PREFERENCIA EN GLORIETA, no respetar',
#        'PEATÓN cruza calz CON PREFER. fuera de PASO (esquina)',
#        'DIRECCIÓN CONTRARIA, circular en',
#        'SIN PODER DETERMINAR, faltan datos',
#        'ESTACIONADO INCORRECTAMENTE',
#        'PREFERENCIA A LA  DERECHA, no respetar',
#        'PREFERENCIA A LA DERECHA, no respetar',
#        'ADELANTAMIENTO incorrecto', 'Daños propiedad', 'Otras causas',
#        'INCORPORARSE un BUS URBANO a la circulac. desde parada señaliz.',
#        'CAIDA DE PEATÓN EN AUTOBUS', 'Daños (Propiedad)', nan,
#        'INCORPORARSE sin las debidas precauciones)',
#        'PEATÓN cruza calz  fuera de PASO (esquina)',
#        'Infracción Penal (sin denuncia)'], dtype=object)

# %%
df = df.sample(200).reset_index(drop=True)
df
# Out:
#                                                     id  year  \
# 0    https://www.zaragoza.es/sede/servicio/transpor...  2013
# 1    https://www.zaragoza.es/sede/servicio/transpor...  2011
# 2    https://www.zaragoza.es/sede/servicio/transpor...  2017
# 3    https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4    https://www.zaragoza.es/sede/servicio/transpor...  2016
# ..                                                 ...   ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...  2012
# 196  https://www.zaragoza.es/sede/servicio/transpor...  2017
# 197  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 198  https://www.zaragoza.es/sede/servicio/transpor...  2016
# 199  https://www.zaragoza.es/sede/servicio/transpor...  2011
#
#                     type  accidentType           firstAddress  \
# 0       COLISIÓN ALCANCE           NaN     ARAGON (CONDES DE)
# 1         SALIDA CALZADA           NaN                 SIGUES
# 2       COLISIÓN ALCANCE           NaN  CIUDAD DEL TRANSPORTE
# 3       COLISIÓN LATERAL           NaN    CONSTITUCION, PASEO
# 4       COLISIÓN ALCANCE           NaN      PAVIA, BATALLA DE
# ..                   ...           ...                    ...
# 195  COLIS FRONTOLATERAL           NaN           GALE, FELISA
# 196  CAIDA SOBRE CALZADA           NaN   HISPANIDAD, RONDA DE
# 197            ATROPELLO           NaN  PUENTE VIRREY, CAMINO
# 198       SALIDA CALZADA           NaN   GARCIA CONDOY, JULIO
# 199       SALIDA CALZADA           NaN  SALAMERO,MIGUEL PLAZA
#
#             secondAddress                                geometry  \
# 0                     NaN   -0.907177956982534,41.636707070239154
# 1                     NaN   -0.9121853015515464,41.64551477523114
# 2                     NaN    -0.8520714973682553,41.7148654402044
# 3         SIMON, AGUSTINA  -0.8838711146455244,41.647890597261465
# 4                     NaN  -0.8669190634975679,41.644080306801825
# ..                    ...                                     ...
# 195  CATALUÑA, AVENIDA DE  -0.8613346663289732,41.663695333518135
# 196           ACCESO Z-40   -0.8689227283269993,41.62473074937737
# 197                   NaN   -0.8740599524043878,41.63874587147674
# 198                   NaN  -0.8824410797159341,41.630207576639215
# 199                   NaN   -0.8839467920910491,41.65196996726811
#
#                                                 reason    area  \
# 0                  DISTANCIA DE SEGURIDAD, no mantener  4028.0
# 1            PERDIDA del control por FALTA de ATENCIÓN  4510.0
# 2            PERDIDA del control por FALTA de ATENCIÓN  1095.0
# 3    INVADIR otro carril en el mismo sentido de cir...  1219.0
# 4            PERDIDA del control por FALTA de ATENCIÓN  2751.0
# ..                                                 ...     ...
# 195            SEMÁFORO, no respetar prioridad de paso   374.0
# 196          PERDIDA del control por FALTA de ATENCIÓN   774.0
# 197        PEATÓN cruza calz SIN PREFER. fuera de paso     NaN
# 198          PERDIDA del control por FALTA de ATENCIÓN     NaN
# 199          PERDIDA del control por FALTA de ATENCIÓN  5780.0
#
#              creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0    2013-11-04T00:00:00Z              True          False     BUEN ESTADO
# 1    2011-10-08T00:00:00Z             False          False     BUEN ESTADO
# 2    2017-04-04T00:00:00Z              True          False     BUEN ESTADO
# 3    2014-05-16T00:00:00Z              True          False     BUEN ESTADO
# 4    2016-10-06T00:00:00Z              True          False     BUEN ESTADO
# ..                    ...               ...            ...             ...
# 195  2012-01-01T00:00:00Z             False          False     BUEN ESTADO
# 196  2017-03-18T00:00:00Z             False          False     BUEN ESTADO
# 197  2019-10-26T00:00:00Z             False          False     BUEN ESTADO
# 198  2016-08-29T00:00:00Z              True          False     BUEN ESTADO
# 199  2011-12-23T00:00:00Z              True          False     BUEN ESTADO
#
#      tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                    NaN     BUEN ESTADO                  NaN
# 1                    NaN     BUEN ESTADO                  NaN
# 2                    NaN     BUEN ESTADO                  NaN
# 3                    NaN     BUEN ESTADO                  NaN
# 4                    NaN     BUEN ESTADO                  NaN
# ..                   ...             ...                  ...
# 195                  NaN     BUEN ESTADO                  NaN
# 196                  NaN     BUEN ESTADO                  NaN
# 197                  NaN     BUEN ESTADO                  NaN
# 198                  NaN     BUEN ESTADO                  NaN
# 199                  NaN     BUEN ESTADO                  NaN
#
#                                               afectado  \
# 0                                                  NaN
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198                                                NaN
# 199                                                NaN
#
#                                               vehiculo
# 0    https://www.zaragoza.es/sede/servicio/transpor...
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2    https://www.zaragoza.es/sede/servicio/transpor...
# 3    https://www.zaragoza.es/sede/servicio/transpor...
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198  https://www.zaragoza.es/sede/servicio/transpor...
# 199  https://www.zaragoza.es/sede/servicio/transpor...
#
# [200 rows x 18 columns]

# %% [markdown]
# # Coordenadas

# %%
df['geometry']
# Out:
# 0       -0.907177956982534,41.636707070239154
# 1       -0.9121853015515464,41.64551477523114
# 2        -0.8520714973682553,41.7148654402044
# 3      -0.8838711146455244,41.647890597261465
# 4      -0.8669190634975679,41.644080306801825
#                         ...
# 195    -0.8613346663289732,41.663695333518135
# 196     -0.8689227283269993,41.62473074937737
# 197     -0.8740599524043878,41.63874587147674
# 198    -0.8824410797159341,41.630207576639215
# 199     -0.8839467920910491,41.65196996726811
# Name: geometry, Length: 200, dtype: object

# %% [markdown]
# ### Convertir una cadena a dos coordenadas

# %% [markdown]
# guardado en cadena, con esto no se puede hacer el mapa, tenemos que 'parsear' a latitud y longitud

# %%
df['geometry']
# Out:
# 0       -0.907177956982534,41.636707070239154
# 1       -0.9121853015515464,41.64551477523114
# 2        -0.8520714973682553,41.7148654402044
# 3      -0.8838711146455244,41.647890597261465
# 4      -0.8669190634975679,41.644080306801825
#                         ...
# 195    -0.8613346663289732,41.663695333518135
# 196     -0.8689227283269993,41.62473074937737
# 197     -0.8740599524043878,41.63874587147674
# 198    -0.8824410797159341,41.630207576639215
# 199     -0.8839467920910491,41.65196996726811
# Name: geometry, Length: 200, dtype: object

# %%
df['geometry'][0]
# Out:
# '-0.907177956982534,41.636707070239154'

# %%
df['geometry'][0].split(',')
# Out:
# ['-0.907177956982534', '41.636707070239154']

# %%
'1' + '2'
# Out:
# '12'

# %%
float('12')
# Out:
# 12.0

# %%
pointStr = df['geometry'][0].split(',')

# %%
pointStr
# Out:
# ['-0.907177956982534', '41.636707070239154']

# %%
pointStr[0]
# Out:
# '-0.907177956982534'

# %%
float(pointStr[0])
# Out:
# -0.907177956982534

# %%
[float(pointStr[0]),float(pointStr[1])]
# Out:
# [-0.907177956982534, 41.636707070239154]

# %% [markdown]
# ## Longitud y Latitud
# Vamos a hacer dos listas una de longitudes y otra de latitudes
# Explicar:
#  * bucles
#  * añadir a lista

# %%
df['geometry']
# Out:
# 0       -0.907177956982534,41.636707070239154
# 1       -0.9121853015515464,41.64551477523114
# 2        -0.8520714973682553,41.7148654402044
# 3      -0.8838711146455244,41.647890597261465
# 4      -0.8669190634975679,41.644080306801825
#                         ...
# 195    -0.8613346663289732,41.663695333518135
# 196     -0.8689227283269993,41.62473074937737
# 197     -0.8740599524043878,41.63874587147674
# 198    -0.8824410797159341,41.630207576639215
# 199     -0.8839467920910491,41.65196996726811
# Name: geometry, Length: 200, dtype: object

# %%
l = []
l = l + [1,2]
l = l + [3]
l
# Out:
# [1, 2, 3]

# %%
longitudes = []
for coordenadasStr in df['geometry']:
    pointStr = coordenadasStr.split(',')
    longitudes += [float(pointStr[0])]

# %%
latitudes = []
for coordenadasStr in df['geometry']:
    pointStr = coordenadasStr.split(',')
    latitudes += [float(pointStr[1])]

# %%
coordenadas = pd.DataFrame({'long':longitudes,'lat':latitudes})
coordenadas
# Out:
#          long        lat
# 0   -0.907178  41.636707
# 1   -0.912185  41.645515
# 2   -0.852071  41.714865
# 3   -0.883871  41.647891
# 4   -0.866919  41.644080
# ..        ...        ...
# 195 -0.861335  41.663695
# 196 -0.868923  41.624731
# 197 -0.874060  41.638746
# 198 -0.882441  41.630208
# 199 -0.883947  41.651970
#
# [200 rows x 2 columns]

# %%
df
# Out:
#                                                     id  year  \
# 0    https://www.zaragoza.es/sede/servicio/transpor...  2013
# 1    https://www.zaragoza.es/sede/servicio/transpor...  2011
# 2    https://www.zaragoza.es/sede/servicio/transpor...  2017
# 3    https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4    https://www.zaragoza.es/sede/servicio/transpor...  2016
# ..                                                 ...   ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...  2012
# 196  https://www.zaragoza.es/sede/servicio/transpor...  2017
# 197  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 198  https://www.zaragoza.es/sede/servicio/transpor...  2016
# 199  https://www.zaragoza.es/sede/servicio/transpor...  2011
#
#                     type  accidentType           firstAddress  \
# 0       COLISIÓN ALCANCE           NaN     ARAGON (CONDES DE)
# 1         SALIDA CALZADA           NaN                 SIGUES
# 2       COLISIÓN ALCANCE           NaN  CIUDAD DEL TRANSPORTE
# 3       COLISIÓN LATERAL           NaN    CONSTITUCION, PASEO
# 4       COLISIÓN ALCANCE           NaN      PAVIA, BATALLA DE
# ..                   ...           ...                    ...
# 195  COLIS FRONTOLATERAL           NaN           GALE, FELISA
# 196  CAIDA SOBRE CALZADA           NaN   HISPANIDAD, RONDA DE
# 197            ATROPELLO           NaN  PUENTE VIRREY, CAMINO
# 198       SALIDA CALZADA           NaN   GARCIA CONDOY, JULIO
# 199       SALIDA CALZADA           NaN  SALAMERO,MIGUEL PLAZA
#
#             secondAddress                                geometry  \
# 0                     NaN   -0.907177956982534,41.636707070239154
# 1                     NaN   -0.9121853015515464,41.64551477523114
# 2                     NaN    -0.8520714973682553,41.7148654402044
# 3         SIMON, AGUSTINA  -0.8838711146455244,41.647890597261465
# 4                     NaN  -0.8669190634975679,41.644080306801825
# ..                    ...                                     ...
# 195  CATALUÑA, AVENIDA DE  -0.8613346663289732,41.663695333518135
# 196           ACCESO Z-40   -0.8689227283269993,41.62473074937737
# 197                   NaN   -0.8740599524043878,41.63874587147674
# 198                   NaN  -0.8824410797159341,41.630207576639215
# 199                   NaN   -0.8839467920910491,41.65196996726811
#
#                                                 reason    area  \
# 0                  DISTANCIA DE SEGURIDAD, no mantener  4028.0
# 1            PERDIDA del control por FALTA de ATENCIÓN  4510.0
# 2            PERDIDA del control por FALTA de ATENCIÓN  1095.0
# 3    INVADIR otro carril en el mismo sentido de cir...  1219.0
# 4            PERDIDA del control por FALTA de ATENCIÓN  2751.0
# ..                                                 ...     ...
# 195            SEMÁFORO, no respetar prioridad de paso   374.0
# 196          PERDIDA del control por FALTA de ATENCIÓN   774.0
# 197        PEATÓN cruza calz SIN PREFER. fuera de paso     NaN
# 198          PERDIDA del control por FALTA de ATENCIÓN     NaN
# 199          PERDIDA del control por FALTA de ATENCIÓN  5780.0
#
#              creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0    2013-11-04T00:00:00Z              True          False     BUEN ESTADO
# 1    2011-10-08T00:00:00Z             False          False     BUEN ESTADO
# 2    2017-04-04T00:00:00Z              True          False     BUEN ESTADO
# 3    2014-05-16T00:00:00Z              True          False     BUEN ESTADO
# 4    2016-10-06T00:00:00Z              True          False     BUEN ESTADO
# ..                    ...               ...            ...             ...
# 195  2012-01-01T00:00:00Z             False          False     BUEN ESTADO
# 196  2017-03-18T00:00:00Z             False          False     BUEN ESTADO
# 197  2019-10-26T00:00:00Z             False          False     BUEN ESTADO
# 198  2016-08-29T00:00:00Z              True          False     BUEN ESTADO
# 199  2011-12-23T00:00:00Z              True          False     BUEN ESTADO
#
#      tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                    NaN     BUEN ESTADO                  NaN
# 1                    NaN     BUEN ESTADO                  NaN
# 2                    NaN     BUEN ESTADO                  NaN
# 3                    NaN     BUEN ESTADO                  NaN
# 4                    NaN     BUEN ESTADO                  NaN
# ..                   ...             ...                  ...
# 195                  NaN     BUEN ESTADO                  NaN
# 196                  NaN     BUEN ESTADO                  NaN
# 197                  NaN     BUEN ESTADO                  NaN
# 198                  NaN     BUEN ESTADO                  NaN
# 199                  NaN     BUEN ESTADO                  NaN
#
#                                               afectado  \
# 0                                                  NaN
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198                                                NaN
# 199                                                NaN
#
#                                               vehiculo
# 0    https://www.zaragoza.es/sede/servicio/transpor...
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2    https://www.zaragoza.es/sede/servicio/transpor...
# 3    https://www.zaragoza.es/sede/servicio/transpor...
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198  https://www.zaragoza.es/sede/servicio/transpor...
# 199  https://www.zaragoza.es/sede/servicio/transpor...
#
# [200 rows x 18 columns]

# %%
latitudes[:10]
# Out:
# [41.636707070239154,
#  41.64551477523114,
#  41.7148654402044,
#  41.647890597261465,
#  41.644080306801825,
#  41.65032945543376,
#  41.63073944645148,
#  41.6518676066259,
#  41.67812441175332,
#  41.63361539996813]

# %% [markdown]
# En este punto tenemos dos listas, una con las longitudes, otra con las latitudes.
# Vamos a construir un DataFrame con estos datos
#  * vamos a usar el indice para poder relacionar, concatenar las tablas

# %%
pd.DataFrame({'col1':[1,2,3],'col2':[4,5,6]})
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %% [markdown]
# Creamos una tabla con el tipo longitud y latitud

# %%
df['type']
# Out:
# 0         COLISIÓN ALCANCE
# 1           SALIDA CALZADA
# 2         COLISIÓN ALCANCE
# 3         COLISIÓN LATERAL
# 4         COLISIÓN ALCANCE
#               ...
# 195    COLIS FRONTOLATERAL
# 196    CAIDA SOBRE CALZADA
# 197              ATROPELLO
# 198         SALIDA CALZADA
# 199         SALIDA CALZADA
# Name: type, Length: 200, dtype: object

# %%
accidentes = pd.concat([df['type'],coordenadas],axis=1)

# %%
accidentes
# Out:
#                     type      long        lat
# 0       COLISIÓN ALCANCE -0.907178  41.636707
# 1         SALIDA CALZADA -0.912185  41.645515
# 2       COLISIÓN ALCANCE -0.852071  41.714865
# 3       COLISIÓN LATERAL -0.883871  41.647891
# 4       COLISIÓN ALCANCE -0.866919  41.644080
# ..                   ...       ...        ...
# 195  COLIS FRONTOLATERAL -0.861335  41.663695
# 196  CAIDA SOBRE CALZADA -0.868923  41.624731
# 197            ATROPELLO -0.874060  41.638746
# 198       SALIDA CALZADA -0.882441  41.630208
# 199       SALIDA CALZADA -0.883947  41.651970
#
# [200 rows x 3 columns]

# %% [markdown]
# En este punto queremos 'concatenar' la tabla con el motivo y las coordenadas.
# De manera parecida a los graficos del otro día

# %%
accidentes
# Out:
#                     type      long        lat
# 0       COLISIÓN ALCANCE -0.907178  41.636707
# 1         SALIDA CALZADA -0.912185  41.645515
# 2       COLISIÓN ALCANCE -0.852071  41.714865
# 3       COLISIÓN LATERAL -0.883871  41.647891
# 4       COLISIÓN ALCANCE -0.866919  41.644080
# ..                   ...       ...        ...
# 195  COLIS FRONTOLATERAL -0.861335  41.663695
# 196  CAIDA SOBRE CALZADA -0.868923  41.624731
# 197            ATROPELLO -0.874060  41.638746
# 198       SALIDA CALZADA -0.882441  41.630208
# 199       SALIDA CALZADA -0.883947  41.651970
#
# [200 rows x 3 columns]

# %% [markdown]
# accidentes.assign(lat=latitudes)

# %% [markdown]
# accidentes

# %% [markdown]
# accidentes['long'] = longitudes

# %% [markdown]
# accidentes

# %% [markdown]
# # Crear el Mapa

# %%
mapa = folium.Map(location=[41.64,-0.88])

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_05eef59e187b433780c21fc908f9d604%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_05eef59e187b433780c21fc908f9d604%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_05eef59e187b433780c21fc908f9d604%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_05eef59e187b433780c21fc908f9d604%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.64%2C%20-0.88%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
mapa = folium.Map(location=[41.64,-0.88])

# %%
marcador = folium.Marker([41.64,-0.88], popup="Zaragoza")

# %%
mapa = mapa.add_child(marcador)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_20a23f7c5e734e9f9f41228da3befa5e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_20a23f7c5e734e9f9f41228da3befa5e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_20a23f7c5e734e9f9f41228da3befa5e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_20a23f7c5e734e9f9f41228da3befa5e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.64%2C%20-0.88%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# # construir un mapa interactivo a partir de la tabla

# %%
mapa = folium.Map(location=[41.649693,-0.887712])

# %%
for indice, fila in accidentes.iterrows():
    marcador = folium.Marker([fila['lat'],fila['long']],\
                             popup=fila['type'])
    mapa.add_child(marcador)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_00f9b33453b94c6c8f6ece368e3a27d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_00f9b33453b94c6c8f6ece368e3a27d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_00f9b33453b94c6c8f6ece368e3a27d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_00f9b33453b94c6c8f6ece368e3a27d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.649693%2C%20-0.887712%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
accidentes
# Out:
#                     type      long        lat
# 0       COLISIÓN ALCANCE -0.907178  41.636707
# 1         SALIDA CALZADA -0.912185  41.645515
# 2       COLISIÓN ALCANCE -0.852071  41.714865
# 3       COLISIÓN LATERAL -0.883871  41.647891
# 4       COLISIÓN ALCANCE -0.866919  41.644080
# ..                   ...       ...        ...
# 195  COLIS FRONTOLATERAL -0.861335  41.663695
# 196  CAIDA SOBRE CALZADA -0.868923  41.624731
# 197            ATROPELLO -0.874060  41.638746
# 198       SALIDA CALZADA -0.882441  41.630208
# 199       SALIDA CALZADA -0.883947  41.651970
#
# [200 rows x 3 columns]

# %%
for indice, fila in accidentes.iterrows():
# Out:
#   File "/tmp/ipykernel_315696/1632637675.py", line 2
#
#     ^
# IndentationError: expected an indented block

# %%
m = folium.Map()

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fa3c1e57944948159a91a334a0cfec52%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fa3c1e57944948159a91a334a0cfec52%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fa3c1e57944948159a91a334a0cfec52%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fa3c1e57944948159a91a334a0cfec52%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %%
m = folium.Map(location=[41.649693,-0.887712], tiles="Stamen Terrain")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_af1e127fd57d4064b5c8a2b6e9958b32%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_af1e127fd57d4064b5c8a2b6e9958b32%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_af1e127fd57d4064b5c8a2b6e9958b32%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_af1e127fd57d4064b5c8a2b6e9958b32%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.649693%2C%20-0.887712%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
marcador = folium.Marker(location=[41.649693,-0.887712],icon=folium.Icon(color="red"))

# %%
m.add_child(marcador)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_af1e127fd57d4064b5c8a2b6e9958b32%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_af1e127fd57d4064b5c8a2b6e9958b32%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_af1e127fd57d4064b5c8a2b6e9958b32%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_af1e127fd57d4064b5c8a2b6e9958b32%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.649693%2C%20-0.887712%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
